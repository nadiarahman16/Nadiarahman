# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiarahman16/Nadiarahman/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
courses = []
choice = 'random'

def line():
    print('------------------')

def menu():
    print('MENU')
    print('1. Add course')
    print('2. Remove course')
    print('3. View courses')
    print('4. Exit')
    line()
    choice = input('Enter your choice: ')
    return choice

while choice != '4':
    choice = menu()
    if choice == '1':
        course = input('Enter course name :')
        courses.append(course)
        print('Course', course, 'added\n')
    elif choice == '2':
        course = input('Enter removed course name :D ')
        if course in crouses:
            courses.remove(course)
            print(course,'course removed' )
        else:
            print('Not found', course)
    elif choice == '3':
        print('View the courses:')
        for course in courses:
            print(course)
    elif choice == '4':
        print('Thank you\n')
    else:
        print('Please enter your choice between 1 to 4 \n')
# Out:
# MENU
# 1. Add course
# 2. Remove course
# 3. View courses
# 4. Exit
# ------------------
# Enter your choice: 1
# Enter course name :AI
# Course AI added
#
# MENU
# 1. Add course
# 2. Remove course
# 3. View courses
# 4. Exit
# ------------------
# Enter your choice: 1
# Enter course name :AI Lab
# Course AI Lab added
#
# MENU
# 1. Add course
# 2. Remove course
# 3. View courses
# 4. Exit
# ------------------
# Enter your choice: DBMS
# Please enter your choice between 1 to 4
#
# MENU
# 1. Add course
# 2. Remove course
# 3. View courses
# 4. Exit
# ------------------
# Enter your choice: 1
# Enter course name :DBMS
# Course DBMS added
#
# MENU
# 1. Add course
# 2. Remove course
# 3. View courses
# 4. Exit
# ------------------
# Enter your choice: 1
# Enter course name :DBMS Lab
# Course DBMS Lab added
#
# MENU
# 1. Add course
# 2. Remove course
# 3. View courses
# 4. Exit
# ------------------
# Enter your choice: 2
# Enter removed course name :D CN
# Not found CN
# MENU
# ...
